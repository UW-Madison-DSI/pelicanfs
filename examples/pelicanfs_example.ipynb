# %% [markdown]
# # PelicanFS Example
#
# An example demonstrating the various ways to use the PelicanFS fsspec with data.

# %%
# Display output of plots directly in Notebook
import xarray as xr
import fsspec
from pelicanfs.core import PelicanFileSystem, PelicanMap

# %% [markdown]
# ## Using the PelicanFS Direction
#
# The following example instantiates and `PelicanFileSystem` with the OSDF Federation Discovery URL and then lists all the files in the `ncar` namespace below the `rda` folder.

# %%
pelfs = PelicanFileSystem("pelican://osg-htc.org")
pelfs.ls("/ncar/rda")
# Out:
# [{'name': '/ncar/rda/d314003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d208000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d744000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d611000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d398000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d606005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789073', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583107', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d728002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789057', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d132000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651062', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d728004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d131002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d277003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d507000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d290000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d629004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d564000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d318000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d608000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d431000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d316001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d721000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d232001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d111003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d318006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d628005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d744005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d473003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d742003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010049', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d676001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d476000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d277007', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789099', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789098', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d287000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d131001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789041', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d718000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789025', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d115004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d126001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d239000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d106000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d217001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d292003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d233005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d115002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d628004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010026', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d570001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d258004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d207000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d743000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d390005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d121001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d320000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d390001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d610000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d018000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d117007', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d554000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d131000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d756005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d075000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/harshah', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789083', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d506000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789067', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d316006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789066', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d111001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d317000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d607000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d430000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d122002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d720000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010065', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d628003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d606003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d742001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651007', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583122', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d531000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d898000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d629006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d475000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d728007', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d195001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d353002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d342000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d728009', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d286000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d370001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d830000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d718005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d461001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651010', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d238000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583123', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d528000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789051', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d119005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d552001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651016', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789035', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d875000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d628002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789034', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d629000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d727001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583128', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789019', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d206000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d742000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789018', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d686000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583110', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/cdgtmp', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d083003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d314006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d330003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010083', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d256004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d542001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d505000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d091001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d577005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d285004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789109', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651025', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583129', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d570003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d633001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d316000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789093', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789092', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789077', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651033', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d127000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d258003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d628001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789076', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/access_report.txt', 'size': None, 'type': 'file'},
#  {'name': '/ncar/rda/d240000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d530000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d820000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651039', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583116', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d474000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d228000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d905000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d285000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d256001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d716000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010077', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d237000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d277002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651042', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d104000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d640000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d313002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651048', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d628000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d205000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d741000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d094002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651050', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d312006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789061', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d685000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d517001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d262000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789060', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010056', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651056', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d552000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789045', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d542003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583104', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789044', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789028', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d277006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d111004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d504000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010054', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651051', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d061001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d473005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d108003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d315000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651057', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d580005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d605000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d259000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d126000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d541002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651065', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d473000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d640006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d340000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789086', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d510002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d904000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d609003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789013', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789012', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d317001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d236000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d402002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d526000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d816000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d501005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d337000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d318004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d627000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d115005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d740000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d633002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d394000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d684000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789103', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d132001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d551000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d463003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d085002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d769000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d111002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d127001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d629005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789070', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d503000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d999005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789054', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d302004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d218001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789038', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d560000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d314000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d850000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d604000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d258000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d122001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d548000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d640002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d213001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d069000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d482001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d359000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d472000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d260003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d117001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d208001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d319002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d283000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d117003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d368000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789096', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d235000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d307007', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d102000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583120', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d469000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d292000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d582000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d292001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d336000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789022', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d626000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d313003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d018001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d260000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d287001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d550000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010043', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d768000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/cesmtmp', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d462001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d502000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/kerchunk_refs', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d579000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d553001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d824001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d736000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d313000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583126', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d603000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d728001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789080', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d257000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d277001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651014', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d370000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d548001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d110003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789064', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d124000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d728003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d950000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789048', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d068000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d358000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d471000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651022', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d761000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/.writable', 'size': None, 'type': 'file'},
#  {'name': '/ncar/rda/d902000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651028', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d302002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d633003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d307003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d083002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d367000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d234000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010018', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d770000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d524000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d814000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d629001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/all_file.txt', 'size': None, 'type': 'file'},
#  {'name': '/ncar/rda/d758000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d256003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583114', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d335000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d871000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d900001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d625000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d710005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d127002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651031', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d533001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d279000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d392000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d082001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d682000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d578005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651037', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d111005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d316009', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d606004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789032', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789016', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d070000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d767000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651045', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d090002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d501000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d578000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d570004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d117006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d735000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d741005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d312000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d099000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d463002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d602000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d389000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651040', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d679000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d256000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d546000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d307009', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789107', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d123000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d548002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651046', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789106', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d067004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d067003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d067001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d067000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583102', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d470000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789090', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d609001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d760000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789074', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651054', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d901000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d281000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d805002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789058', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d312009', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d285003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d309000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d712000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d366000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d233000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d523000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d728006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d100000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d467000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d757000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d580000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d870000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d190003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d201000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583108', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d278000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d391000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651063', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d510006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d681000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d012000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d709000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d766000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d115006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d633000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d195005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d318001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d505001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789042', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d867000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789026', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d734000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d540006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d601000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d388000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d678000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d255000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d633004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d545000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d122000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d548003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d489000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d069005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d066000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d606002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d540007', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d900000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d280000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d744003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d308000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583130', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d711000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d759001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789084', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d365000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d119000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d232000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789068', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d123001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d540008', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d522000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d289002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/README_rda-data_contents', 'size': None, 'type': 'file'},
#  {'name': '/ncar/rda/d466000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789010', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d118001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d200000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d390004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d277000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d390000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d580007', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d132002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d680000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d209001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d540009', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d640005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d491000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d541003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d744008', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d765000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d113001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789101', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789100', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d840001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d576000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d866000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d082005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d744001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d733000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d310000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651008', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d600000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d387000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d564001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d677000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d254000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d544000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789052', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d121000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d198000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789036', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d488000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d065000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d553002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d355000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d891000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d222000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d463001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651009', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d631004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651011', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d307000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d710000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d497000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583124', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651017', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d744006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d118000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d231000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d521000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d888000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d111006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d219000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d755000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d209003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789094', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d820001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d195002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583111', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d276000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/icoads', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010062', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789020', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d093001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d628009', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651020', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d087000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d633005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d490000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d578002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d764000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651026', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d518000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d539001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d808000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d631000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d575000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d865000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d260004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d619000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651034', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d732000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d319003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583112', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d630001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d386000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d676000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d507005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d253000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d543000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d805001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d083001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d120000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d197000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583117', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d487000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d625001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d258001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d354000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651035', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789062', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d628008', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d999008', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d800001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d742006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789046', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d729000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651043', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789029', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d496000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d629002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d117000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651049', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d230000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583118', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d520000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d810000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d353004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d464000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d218000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d754000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d621000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010035', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d275000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583105', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d086000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d742005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651052', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789088', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789087', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d517000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d630000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651058', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789030', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d038000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d574000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651060', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789014', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d618000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d731000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651066', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d115007', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d252000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d542000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d260002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d486000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d510005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d063000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d353000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d197009', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d220000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d759002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d684001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d628006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789104', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d319001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d728000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d841000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d314002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d285006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d495000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789072', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d539000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d362000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789071', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789056', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d633006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d318005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d121002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d314001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789055', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789039', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d463000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d359005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d217000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d330000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d620000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d274000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d502003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d578001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/newMESACLIP', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d129001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d085000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d285002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d725002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d762000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d516000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d806000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d313006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d124001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d573000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d390006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d863000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d617000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d542002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d730000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010047', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d094000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789097', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d119001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d627002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d251000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d388001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789040', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d541000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d195000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789024', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d485000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789023', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d062000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d352000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d210001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d292002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d117005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d750001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d841001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d727000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d304000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d840000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d745001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d361000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d565001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d115000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583121', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d462000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d289001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789082', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d740001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d020001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789081', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d119003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d273000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d539006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789065', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d464001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789049', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d084000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d824002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d728005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/addlink.sh', 'size': None, 'type': 'file'},
#  {'name': '/ncar/rda/d515000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d542004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d805000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d302005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d999007', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d279001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d036000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d572000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d672005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d862000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651015', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d616000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583127', 'size': None, 'type': 'directory'},
# ...
#  {'name': '/ncar/rda/d473002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d530001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d836000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d703000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d083000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d117008', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789091', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d514000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d804000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d345001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789059', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651041', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d571000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d885001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d313007', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d861000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d615000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d092000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651047', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d559000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d520001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d672000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d759003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583103', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d193000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651055', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d483000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d060000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d605005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d728008', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d539005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d606001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d999009', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d084002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d302003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d435000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d725000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d629003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d302000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d510001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d609002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d113000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d403000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789043', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d578003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789027', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d460000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651064', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d750000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d307005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583109', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d510004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d271000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d702000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d318002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d082000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d513000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d315001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d570000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d860000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d502001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d614000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d765005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789085', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d091000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d381000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d318003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d084003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d353003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d671000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789069', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d482000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789011', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d850001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d240006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010048', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/.test', 'size': None, 'type': 'file'},
#  {'name': '/ncar/rda/d010091', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d258002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d845001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d724000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d394001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d301000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d535000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789102', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d112000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d825000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d756001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d402000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d115003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d120001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d213000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d277004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d841006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d480001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d119002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d270000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789053', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d115001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d302001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d834000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789037', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d701000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d081000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d314008', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d084004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010100', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d109000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d645000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d285005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d512000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d299000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d110001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d199001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d082002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d746000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d277008', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d613000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d741001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d267000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d090000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d313008', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d126002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d465001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d191000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d481000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789095', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d285001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d509000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651012', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789079', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d119004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d640001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d570002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d856000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651018', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789021', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d723000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d300000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583125', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d111000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d401000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d188000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d726001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651013', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d345000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d084005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651019', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d909000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d289000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651021', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d692000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d845002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d744004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d232003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d721001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651027', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d516002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d700000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/rda-quasar', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d080000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d541001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d090001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d108000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/CREDIT_ERA5_zarr', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789063', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d511000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d298000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d801000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789047', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d256002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d209000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d745000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d085001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/pythia_era5_24', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583113', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d759004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d612000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d627001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d556000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651030', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d260001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010080', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d190000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651036', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d744009', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d480000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d351001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583100', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d682003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d508000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d698000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d117002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651044', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d330002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d565000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d744002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d855000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d084006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d609000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d701005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d722000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789089', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583119', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d533000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d110000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d117004', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d400000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789031', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583101', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d232002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d010014', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789015', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d880000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d516001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d691000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d605002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d583106', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651053', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d719000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d124002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d131003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d832000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d240001', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d744007', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651059', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d209002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d270002', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d107000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d651061', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d240005', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d510000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d067006', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d789105', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d640003', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d800000', 'size': None, 'type': 'directory'},
#  {'name': '/ncar/rda/d602001', 'size': None, 'type': 'directory'}]

# %% [markdown]
# ## Using the Pelican Map
#
# The following example shows loading in a file as a PelicanMap using the previous PelicanFileSytem object (which uses the `odsf` director)

# %%
file = PelicanMap(
    "/chtc/PUBLIC/eturetsky/ncar-subset/ncar/monthly/cesm2LE-historical-cmip6-FLUT.zarr", pelfs, check=True, create=True
)
# Out:
# No working cache found
# ---------------------------------------------------------------------------
# NoAvailableSource                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 file = PelicanMap("/chtc/PUBLIC/eturetsky/ncar-subset/ncar/monthly/cesm2LE-historical-cmip6-FLUT.zarr", pelfs, check=True, create=True)
#
# File ~/repo/pelicanfs/src/pelicanfs/core.py:843, in PelicanMap(root, pelfs, check, create)
#     839 def PelicanMap(root, pelfs: PelicanFileSystem, check=False, create=False):
#     840     """
#     841     Returns and FSMap object assigning creating a mutable mapper at the root location
#     842     """
# --> 843     return pelfs.get_mapper(root, check=check, create=create)
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/fsspec/spec.py:1576, in AbstractFileSystem.get_mapper(self, root, check, create, missing_exceptions)
#    1569 """Create key/value store based on this file-system
#    1570
#    1571 Makes a MutableMapping interface to the FS at the given root path.
#    1572 See ``fsspec.mapping.FSMap`` for further details.
#    1573 """
#    1574 from .mapping import FSMap
# -> 1576 return FSMap(
#    1577     root,
#    1578     self,
#    1579     check=check,
#    1580     create=create,
#    1581     missing_exceptions=missing_exceptions,
#    1582 )
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/fsspec/mapping.py:55, in FSMap.__init__(self, root, fs, check, create, missing_exceptions)
#      53 self.create = create
#      54 if create:
# ---> 55     if not self.fs.exists(root):
#      56         self.fs.mkdir(root)
#      57 if check:
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File ~/repo/pelicanfs/src/pelicanfs/core.py:734, in PelicanFileSystem._cache_dec.<locals>.wrapper(self, *args, **kwargs)
#     732     data_url = await self.get_origin_url(path)
#     733 else:
# --> 734     data_url = await self.get_working_cache(path)
#     735 try:
#     736     logger.debug(f"Calling {func} using the following url: {data_url}")
#
# File ~/repo/pelicanfs/src/pelicanfs/core.py:380, in PelicanFileSystem.get_working_cache(self, fileloc)
#     378 if not cache_list:
#     379     logger.error("No working cache found")
# --> 380     raise NoAvailableSource()
#     382 with self._namespace_lock:
#     383     self._namespace_cache[namespace] = _CacheManager(cache_list)
#
# NoAvailableSource:

# %%
test = xr.open_dataset(file, engine="zarr")
test

# %% [markdown]
# ## Using an the OSDF protocol directly
#
# The following example shows how to use the `osdf://` protocol plus the filepath within the namespace to open a dataset

# %%
test = xr.open_dataset(
    "osdf:///chtc/PUBLIC/eturetsky/ncar-subset/ncar/monthly/cesm2LE-historical-cmip6-FLUT.zarr", engine="zarr"
)
test
# Out:
# No working cache found
# No working cache found
# No working cache found
# ---------------------------------------------------------------------------
# NoAvailableSource                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 test = xr.open_dataset(
#       2     "osdf:///chtc/PUBLIC/eturetsky/ncar-subset/ncar/monthly/cesm2LE-historical-cmip6-FLUT.zarr", engine="zarr"
#       3 )
#       4 test
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/xarray/backends/api.py:715, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     703 decoders = _resolve_decoders_kwargs(
#     704     decode_cf,
#     705     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)    711     decode_coords=decode_coords,
#     712 )
#     714 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 715 backend_ds = backend.open_dataset(
#     716     filename_or_obj,
#     717     drop_variables=drop_variables,
#     718     **decoders,
#     719     **kwargs,
#     720 )
#     721 ds = _dataset_from_backend_dataset(
#     722     backend_ds,
#     723     filename_or_obj,
#    (...)    734     **kwargs,
#     735 )
#     736 return ds
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/xarray/backends/zarr.py:1587, in ZarrBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, zarr_version, zarr_format, store, engine, use_zarr_fill_value_as_mask, cache_members)
#    1585 filename_or_obj = _normalize_path(filename_or_obj)
#    1586 if not store:
# -> 1587     store = ZarrStore.open_group(
#    1588         filename_or_obj,
#    1589         group=group,
#    1590         mode=mode,
#    1591         synchronizer=synchronizer,
#    1592         consolidated=consolidated,
#    1593         consolidate_on_close=False,
#    1594         chunk_store=chunk_store,
#    1595         storage_options=storage_options,
#    1596         zarr_version=zarr_version,
#    1597         use_zarr_fill_value_as_mask=None,
#    1598         zarr_format=zarr_format,
#    1599         cache_members=cache_members,
#    1600     )
#    1602 store_entrypoint = StoreBackendEntrypoint()
#    1603 with close_on_error(store):
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/xarray/backends/zarr.py:664, in ZarrStore.open_group(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region, safe_chunks, align_chunks, zarr_version, zarr_format, use_zarr_fill_value_as_mask, write_empty, cache_members)
#     638 @classmethod
#     639 def open_group(
#     640     cls,
#    (...)    657     cache_members: bool = True,
#     658 ):
#     659     (
#     660         zarr_group,
#     661         consolidate_on_close,
#     662         close_store_on_close,
#     663         use_zarr_fill_value_as_mask,
# --> 664     ) = _get_open_params(
#     665         store=store,
#     666         mode=mode,
#     667         synchronizer=synchronizer,
#     668         group=group,
#     669         consolidated=consolidated,
#     670         consolidate_on_close=consolidate_on_close,
#     671         chunk_store=chunk_store,
#     672         storage_options=storage_options,
#     673         zarr_version=zarr_version,
#     674         use_zarr_fill_value_as_mask=use_zarr_fill_value_as_mask,
#     675         zarr_format=zarr_format,
#     676     )
#     678     return cls(
#     679         zarr_group,
#     680         mode,
#    (...)    689         cache_members=cache_members,
#     690     )
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/xarray/backends/zarr.py:1795, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1792 elif consolidated is None:
#    1793     # same but with more error handling in case no consolidated metadata found
#    1794     try:
# -> 1795         zarr_root_group = zarr.open_consolidated(store, **open_kwargs)
#    1796     except (ValueError, KeyError):
#    1797         # ValueError in zarr-python 3.x, KeyError in 2.x.
#    1798         try:
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/zarr/api/synchronous.py:222, in open_consolidated(use_consolidated, *args, **kwargs)
#     217 def open_consolidated(*args: Any, use_consolidated: Literal[True] = True, **kwargs: Any) -> Group:
#     218     """
#     219     Alias for :func:`open_group` with ``use_consolidated=True``.
#     220     """
#     221     return Group(
# --> 222         sync(async_api.open_consolidated(*args, use_consolidated=use_consolidated, **kwargs))
#     223     )
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/zarr/core/sync.py:163, in sync(coro, loop, timeout)
#     160 return_result = next(iter(finished)).result()
#     162 if isinstance(return_result, BaseException):
# --> 163     raise return_result
#     164 else:
#     165     return return_result
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/zarr/core/sync.py:119, in _runner(coro)
#     114 """
#     115 Await a coroutine and return the result of running it. If awaiting the coroutine raises an
#     116 exception, the exception will be returned.
#     117 """
#     118 try:
# --> 119     return await coro
#     120 except Exception as ex:
#     121     return ex
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/zarr/api/asynchronous.py:382, in open_consolidated(use_consolidated, *args, **kwargs)
#     377 if use_consolidated is not True:
#     378     raise TypeError(
#     379         "'use_consolidated' must be 'True' in 'open_consolidated'. Use 'open' with "
#     380         "'use_consolidated=False' to bypass consolidated metadata."
#     381     )
# --> 382 return await open_group(*args, use_consolidated=use_consolidated, **kwargs)
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/zarr/api/asynchronous.py:845, in open_group(store, mode, cache_attrs, synchronizer, path, chunk_store, storage_options, zarr_version, zarr_format, meta_array, attributes, use_consolidated)
#     843 try:
#     844     if mode in _READ_MODES:
# --> 845         return await AsyncGroup.open(
#     846             store_path, zarr_format=zarr_format, use_consolidated=use_consolidated
#     847         )
#     848 except (KeyError, FileNotFoundError):
#     849     pass
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/zarr/core/group.py:542, in AsyncGroup.open(cls, store, zarr_format, use_consolidated)
#     535         raise FileNotFoundError(store_path)
#     536 elif zarr_format is None:
#     537     (
#     538         zarr_json_bytes,
#     539         zgroup_bytes,
#     540         zattrs_bytes,
#     541         maybe_consolidated_metadata_bytes,
# --> 542     ) = await asyncio.gather(
#     543         (store_path / ZARR_JSON).get(),
#     544         (store_path / ZGROUP_JSON).get(),
#     545         (store_path / ZATTRS_JSON).get(),
#     546         (store_path / str(consolidated_key)).get(),
#     547     )
#     548     if zarr_json_bytes is not None and zgroup_bytes is not None:
#     549         # warn and favor v3
#     550         msg = f"Both zarr.json (Zarr format 3) and .zgroup (Zarr format 2) metadata objects exist at {store_path}. Zarr format 3 will be used."
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/zarr/storage/_common.py:164, in StorePath.get(self, prototype, byte_range)
#     162 if prototype is None:
#     163     prototype = default_buffer_prototype()
# --> 164 return await self.store.get(self.path, prototype=prototype, byte_range=byte_range)
#
# File ~/repo/pelicanfs/.venv/lib/python3.11/site-packages/zarr/storage/_fsspec.py:300, in FsspecStore.get(self, key, prototype, byte_range)
#     298 try:
#     299     if byte_range is None:
# --> 300         value = prototype.buffer.from_bytes(await self.fs._cat_file(path))
#     301     elif isinstance(byte_range, RangeByteRequest):
#     302         value = prototype.buffer.from_bytes(
#     303             await self.fs._cat_file(
#     304                 path,
#    (...)    307             )
#     308         )
#
# File ~/repo/pelicanfs/src/pelicanfs/core.py:734, in PelicanFileSystem._cache_dec.<locals>.wrapper(self, *args, **kwargs)
#     732     data_url = await self.get_origin_url(path)
#     733 else:
# --> 734     data_url = await self.get_working_cache(path)
#     735 try:
#     736     logger.debug(f"Calling {func} using the following url: {data_url}")
#
# File ~/repo/pelicanfs/src/pelicanfs/core.py:380, in PelicanFileSystem.get_working_cache(self, fileloc)
#     378 if not cache_list:
#     379     logger.error("No working cache found")
# --> 380     raise NoAvailableSource()
#     382 with self._namespace_lock:
#     383     self._namespace_cache[namespace] = _CacheManager(cache_list)
#
# NoAvailableSource:
# No working cache found

# %% [markdown]
# ## Use FSSpec directly
#
# Since PelicanFS is a registered backend with fsspec, it can also be used directly with fsspec with either the `osdf://` or `pelican://` protocols.

# %%
open_test = fsspec.open(
    "osdf:///chtc/PUBLIC/eturetsky/ncar-subset/ncar/monthly/cesm2LE-historical-cmip6-FLUT.zarr/.zmetadata"
)
open_test
# Out:
# <OpenFile '/chtc/PUBLIC/eturetsky/ncar-subset/ncar/monthly/cesm2LE-historical-cmip6-FLUT.zarr/.zmetadata'>
